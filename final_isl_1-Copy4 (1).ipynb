# %%
import cv2
import mediapipe as mp
import numpy as np
import os
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
mp_holistic = mp.solutions.holistic  # Holistic model
mp_drawing = mp.solutions.drawing_utils  # Drawing utilities

# Set up Holistic model
holistic = mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# %%
import numpy as np
import time
import cv2
import os
import mediapipe as mp

# Initialize Mediapipe Hand model
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

# Initialize video capture
cap = cv2.VideoCapture(0)

# Function to extract keypoints from Mediapipe results (hand landmarks only)
def extract_keypoints(results):
    keypoints = []
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            for landmark in hand_landmarks.landmark:
                keypoints.extend([landmark.x, landmark.y, landmark.z])
    return keypoints

# Function to save data and display messages
def save_data(action, frame_num, keypoints, image):
    try:
        action_path = os.path.join('MP_Data3', action)
        os.makedirs(action_path, exist_ok=True)  # Create directory if it doesn't exist

        # Save keypoints data
        npy_path = os.path.join(action_path, f"{frame_num}.npy")
        np.save(npy_path, keypoints)

        # Save the corresponding image
        frame_image_path = os.path.join(action_path, f"{frame_num}.jpg")
        cv2.imwrite(frame_image_path, image)

        print(f"Saved data for {action}: Frame {frame_num + 1}")
    except Exception as e:
        print(f"Error saving data: {e}")

# Function to draw a rectangle around the hand based on landmarks
def draw_hand_rectangle(image, hand_landmarks, w, h):
    x_min = min([int(landmark.x * w) for landmark in hand_landmarks.landmark])
    x_max = max([int(landmark.x * w) for landmark in hand_landmarks.landmark])
    y_min = min([int(landmark.y * h) for landmark in hand_landmarks.landmark])
    y_max = max([int(landmark.y * h) for landmark in hand_landmarks.landmark])

    # Add padding for better visibility of the rectangle
    padding = 20
    x_min = max(0, x_min - padding)
    x_max = min(w, x_max + padding)
    y_min = max(0, y_min - padding)
    y_max = min(h, y_max + padding)

    # Draw the rectangle on the image
    cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

# Set up the hand model with adjusted confidence
with mp_hands.Hands(
    min_detection_confidence=0.6,  # Adjusted confidence
    min_tracking_confidence=0.6  # Adjusted confidence
) as hands:

    while True:
        action = input("Enter pose label (hello, this, prototype) or 'q' to quit: ").strip().lower()
        time.sleep(1.5)
        # Handle 'q' input to quit
        if action == 'q':
            print("Quitting...")
            break

        # Ensure a valid action is provided
        if action not in ['hello', 'this', 'prototype','seeyoulater']:
            print("Invalid action label. Please enter a valid label.")
            continue

        print(f"Starting capture for pose: {action}")

        for frame_num in range(50):  # Collect 50 frames per action
            time.sleep(0.5)

            if not cap.isOpened():
                print("Error: Video capture not initialized.")
                break

            ret, frame = cap.read()
            if not ret:
                print("Error: Frame capture failed.")
                continue

            # Get frame dimensions
            h, w, _ = frame.shape

            # Recolor frame to RGB for processing
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False

            # Make hand detections only
            results = hands.process(image)

            # Recolor back to BGR for OpenCV
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # Draw hand landmarks and a rectangle around the hand
            if results.multi_hand_landmarks:
                for hand_landmarks in results.multi_hand_landmarks:
                    # Draw the landmarks on the image
                    mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

                    # Draw a rectangle around the hand
                    draw_hand_rectangle(image, hand_landmarks, w, h)

            # Extract keypoints and save data (hands only)
            keypoints = extract_keypoints(results)
            save_data(action, frame_num, keypoints, image)

            # Display the frame
            cv2.imshow('Webcam Feed', image)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("Capture interrupted by user.")
                break

print("Data collection completed.")
cap.release()
cv2.destroyAllWindows()
# Out:
# Enter pose label (hello, this, prototype) or 'q' to quit: q
# Quitting...
# Data collection completed.

# %%
import os
import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def load_data(data_path):
    X = []
    y = []
    actions = os.listdir(data_path)
    print(f"Actions found: {actions}")

    for action in actions:
        action_path = os.path.join(data_path, action)
        if not os.path.isdir(action_path):
            print(f"Skipping non-directory: {action_path}")
            continue

        files = os.listdir(action_path)
        print(f"Files found for action '{action}': {files}")

        for file in files:
            file_path = os.path.join(action_path, file)
            if file.endswith('.npy'):
                try:
                    keypoints = np.load(file_path)
                    if keypoints.size == 0:
                        print(f"Warning: Empty file {file_path}")
                        continue
                    X.append(keypoints)
                    y.append(action)
                    print(f"Loaded data from {file_path}, shape: {keypoints.shape}")
                except Exception as e:
                    print(f"Error loading {file_path}: {e}")
            else:
                print(f"Skipping non-npy file: {file_path}")

    # Handle inconsistent shapes by padding, truncating, or leaving as list
    max_length = max([item.shape[0] for item in X])
    print(f"Maximum sequence length found: {max_length}")
    X_padded = np.array([np.pad(item, (0, max_length - item.shape[0]), 'constant') if item.shape[0] < max_length else item for item in X])
    y = np.array(y)

    return X_padded, y  # or return X_truncated, y if truncating

# Load data
data_path = 'MP_Data3'
X, y = load_data(data_path)

# Check loaded data
print(f"Loaded {len(X)} samples and {len(y)} labels.")
if len(X) == 0 or len(y) == 0:
    raise ValueError("No data found. Check the data collection and storage process.")

print("Sample X shape:", X.shape)
print("Sample y shape:", y.shape)

# Encode labels
actions = np.unique(y)
print("Actions:", actions)

# Check if y is empty
if len(y) == 0:
    raise ValueError("No data found for encoding. Ensure that data is collected and stored properly.")

y_encoded = np.array([np.where(actions == label)[0][0] for label in y])

# Convert labels to categorical
y_encoded = to_categorical(y_encoded)
print("y_encoded shape:", y_encoded.shape)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
print(f"Training samples: {len(X_train)}, Test samples: {len(X_test)}")
# Out:
# Actions found: ['hello', 'prototype', 'seeyoulater', 'this']
# Files found for action 'hello': ['0.jpg', '0.npy', '1.jpg', '1.npy', '10.jpg', '10.npy', '11.jpg', '11.npy', '12.jpg', '12.npy', '13.jpg', '13.npy', '14.jpg', '14.npy', '15.jpg', '15.npy', '16.jpg', '16.npy', '17.jpg', '17.npy', '18.jpg', '18.npy', '19.jpg', '19.npy', '2.jpg', '2.npy', '20.jpg', '20.npy', '21.jpg', '21.npy', '22.jpg', '22.npy', '23.jpg', '23.npy', '24.jpg', '24.npy', '25.jpg', '25.npy', '26.jpg', '26.npy', '27.jpg', '27.npy', '28.jpg', '28.npy', '29.jpg', '29.npy', '3.jpg', '3.npy', '30.jpg', '30.npy', '31.jpg', '31.npy', '32.jpg', '32.npy', '33.jpg', '33.npy', '34.jpg', '34.npy', '35.jpg', '35.npy', '36.jpg', '36.npy', '37.jpg', '37.npy', '38.jpg', '38.npy', '39.jpg', '39.npy', '4.jpg', '4.npy', '40.jpg', '40.npy', '41.jpg', '41.npy', '42.jpg', '42.npy', '43.jpg', '43.npy', '44.jpg', '44.npy', '45.jpg', '45.npy', '46.jpg', '46.npy', '47.jpg', '47.npy', '48.jpg', '48.npy', '49.jpg', '49.npy', '5.jpg', '5.npy', '6.jpg', '6.npy', '7.jpg', '7.npy', '8.jpg', '8.npy', '9.jpg', '9.npy']
# Skipping non-npy file: MP_Data3\hello\0.jpg
# Loaded data from MP_Data3\hello\0.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\1.jpg
# Loaded data from MP_Data3\hello\1.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\10.jpg
# Loaded data from MP_Data3\hello\10.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\11.jpg
# Loaded data from MP_Data3\hello\11.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\12.jpg
# Loaded data from MP_Data3\hello\12.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\13.jpg
# Loaded data from MP_Data3\hello\13.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\14.jpg
# Loaded data from MP_Data3\hello\14.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\15.jpg
# Loaded data from MP_Data3\hello\15.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\16.jpg
# Loaded data from MP_Data3\hello\16.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\17.jpg
# Loaded data from MP_Data3\hello\17.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\18.jpg
# Loaded data from MP_Data3\hello\18.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\19.jpg
# Loaded data from MP_Data3\hello\19.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\2.jpg
# Loaded data from MP_Data3\hello\2.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\20.jpg
# Loaded data from MP_Data3\hello\20.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\21.jpg
# Loaded data from MP_Data3\hello\21.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\22.jpg
# Loaded data from MP_Data3\hello\22.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\23.jpg
# Loaded data from MP_Data3\hello\23.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\24.jpg
# Loaded data from MP_Data3\hello\24.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\25.jpg
# Loaded data from MP_Data3\hello\25.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\26.jpg
# Loaded data from MP_Data3\hello\26.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\27.jpg
# Loaded data from MP_Data3\hello\27.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\28.jpg
# Loaded data from MP_Data3\hello\28.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\29.jpg
# Loaded data from MP_Data3\hello\29.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\3.jpg
# Loaded data from MP_Data3\hello\3.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\30.jpg
# Loaded data from MP_Data3\hello\30.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\31.jpg
# Loaded data from MP_Data3\hello\31.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\32.jpg
# Loaded data from MP_Data3\hello\32.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\33.jpg
# Loaded data from MP_Data3\hello\33.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\34.jpg
# Loaded data from MP_Data3\hello\34.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\35.jpg
# Loaded data from MP_Data3\hello\35.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\36.jpg
# Loaded data from MP_Data3\hello\36.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\37.jpg
# Loaded data from MP_Data3\hello\37.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\38.jpg
# Loaded data from MP_Data3\hello\38.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\39.jpg
# Loaded data from MP_Data3\hello\39.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\4.jpg
# Loaded data from MP_Data3\hello\4.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\40.jpg
# Loaded data from MP_Data3\hello\40.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\41.jpg
# Loaded data from MP_Data3\hello\41.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\42.jpg
# Loaded data from MP_Data3\hello\42.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\43.jpg
# Loaded data from MP_Data3\hello\43.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\44.jpg
# Loaded data from MP_Data3\hello\44.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\45.jpg
# Loaded data from MP_Data3\hello\45.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\46.jpg
# Loaded data from MP_Data3\hello\46.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\47.jpg
# Loaded data from MP_Data3\hello\47.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\48.jpg
# Loaded data from MP_Data3\hello\48.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\49.jpg
# Loaded data from MP_Data3\hello\49.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\5.jpg
# Loaded data from MP_Data3\hello\5.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\6.jpg
# Loaded data from MP_Data3\hello\6.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\7.jpg
# Loaded data from MP_Data3\hello\7.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\8.jpg
# Loaded data from MP_Data3\hello\8.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\hello\9.jpg
# Loaded data from MP_Data3\hello\9.npy, shape: (63,)
# Files found for action 'prototype': ['0.jpg', '0.npy', '1.jpg', '1.npy', '10.jpg', '10.npy', '11.jpg', '11.npy', '12.jpg', '12.npy', '13.jpg', '13.npy', '14.jpg', '14.npy', '15.jpg', '15.npy', '16.jpg', '16.npy', '17.jpg', '17.npy', '18.jpg', '18.npy', '19.jpg', '19.npy', '2.jpg', '2.npy', '20.jpg', '20.npy', '21.jpg', '21.npy', '22.jpg', '22.npy', '23.jpg', '23.npy', '24.jpg', '24.npy', '25.jpg', '25.npy', '26.jpg', '26.npy', '27.jpg', '27.npy', '28.jpg', '28.npy', '29.jpg', '29.npy', '3.jpg', '3.npy', '30.jpg', '30.npy', '31.jpg', '31.npy', '32.jpg', '32.npy', '33.jpg', '33.npy', '34.jpg', '34.npy', '35.jpg', '35.npy', '36.jpg', '36.npy', '37.jpg', '37.npy', '38.jpg', '38.npy', '39.jpg', '39.npy', '4.jpg', '4.npy', '40.jpg', '40.npy', '41.jpg', '41.npy', '42.jpg', '42.npy', '43.jpg', '43.npy', '44.jpg', '44.npy', '45.jpg', '45.npy', '46.jpg', '46.npy', '47.jpg', '47.npy', '48.jpg', '48.npy', '49.jpg', '49.npy', '5.jpg', '5.npy', '6.jpg', '6.npy', '7.jpg', '7.npy', '8.jpg', '8.npy', '9.jpg', '9.npy']
# Skipping non-npy file: MP_Data3\prototype\0.jpg
# Loaded data from MP_Data3\prototype\0.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\1.jpg
# Loaded data from MP_Data3\prototype\1.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\10.jpg
# Loaded data from MP_Data3\prototype\10.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\11.jpg
# Loaded data from MP_Data3\prototype\11.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\12.jpg
# Loaded data from MP_Data3\prototype\12.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\13.jpg
# Loaded data from MP_Data3\prototype\13.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\14.jpg
# Loaded data from MP_Data3\prototype\14.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\15.jpg
# Loaded data from MP_Data3\prototype\15.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\16.jpg
# Loaded data from MP_Data3\prototype\16.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\17.jpg
# Loaded data from MP_Data3\prototype\17.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\18.jpg
# Loaded data from MP_Data3\prototype\18.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\19.jpg
# Loaded data from MP_Data3\prototype\19.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\2.jpg
# Loaded data from MP_Data3\prototype\2.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\20.jpg
# Loaded data from MP_Data3\prototype\20.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\21.jpg
# Loaded data from MP_Data3\prototype\21.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\22.jpg
# Loaded data from MP_Data3\prototype\22.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\23.jpg
# Loaded data from MP_Data3\prototype\23.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\24.jpg
# Loaded data from MP_Data3\prototype\24.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\25.jpg
# Loaded data from MP_Data3\prototype\25.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\26.jpg
# Loaded data from MP_Data3\prototype\26.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\27.jpg
# Loaded data from MP_Data3\prototype\27.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\28.jpg
# Loaded data from MP_Data3\prototype\28.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\29.jpg
# Loaded data from MP_Data3\prototype\29.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\3.jpg
# Loaded data from MP_Data3\prototype\3.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\30.jpg
# Loaded data from MP_Data3\prototype\30.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\31.jpg
# Loaded data from MP_Data3\prototype\31.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\32.jpg
# Loaded data from MP_Data3\prototype\32.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\33.jpg
# Loaded data from MP_Data3\prototype\33.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\34.jpg
# Loaded data from MP_Data3\prototype\34.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\35.jpg
# Loaded data from MP_Data3\prototype\35.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\36.jpg
# Loaded data from MP_Data3\prototype\36.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\37.jpg
# Loaded data from MP_Data3\prototype\37.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\38.jpg
# Loaded data from MP_Data3\prototype\38.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\39.jpg
# Loaded data from MP_Data3\prototype\39.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\4.jpg
# Loaded data from MP_Data3\prototype\4.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\40.jpg
# Loaded data from MP_Data3\prototype\40.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\41.jpg
# Loaded data from MP_Data3\prototype\41.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\42.jpg
# Loaded data from MP_Data3\prototype\42.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\43.jpg
# Loaded data from MP_Data3\prototype\43.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype\44.jpg
# Loaded data from MP_Data3\prototype\44.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\prototype
npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\1.jpg
# Loaded data from MP_Data3\this\1.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\10.jpg
# Loaded data from MP_Data3\this\10.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\11.jpg
# Loaded data from MP_Data3\this\11.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\12.jpg
# Loaded data from MP_Data3\this\12.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\13.jpg
# Loaded data from MP_Data3\this\13.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\14.jpg
# Loaded data from MP_Data3\this\14.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\15.jpg
# Loaded data from MP_Data3\this\15.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\16.jpg
# Loaded data from MP_Data3\this\16.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\17.jpg
# Loaded data from MP_Data3\this\17.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\18.jpg
# Loaded data from MP_Data3\this\18.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\19.jpg
# Loaded data from MP_Data3\this\19.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\2.jpg
# Loaded data from MP_Data3\this\2.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\20.jpg
# Loaded data from MP_Data3\this\20.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\21.jpg
# Loaded data from MP_Data3\this\21.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\22.jpg
# Loaded data from MP_Data3\this\22.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\23.jpg
# Loaded data from MP_Data3\this\23.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\24.jpg
# Loaded data from MP_Data3\this\24.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\25.jpg
# Loaded data from MP_Data3\this\25.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\26.jpg
# Loaded data from MP_Data3\this\26.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\27.jpg
# Loaded data from MP_Data3\this\27.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\28.jpg
# Loaded data from MP_Data3\this\28.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\29.jpg
# Loaded data from MP_Data3\this\29.npy, shape: (126,)
# Skipping non-npy file: MP_Data3\this\3.jpg
# Loaded data from MP_Data3\this\3.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\30.jpg
# Loaded data from MP_Data3\this\30.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\31.jpg
# Loaded data from MP_Data3\this\31.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\32.jpg
# Loaded data from MP_Data3\this\32.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\33.jpg
# Loaded data from MP_Data3\this\33.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\34.jpg
# Loaded data from MP_Data3\this\34.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\35.jpg
# Loaded data from MP_Data3\this\35.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\36.jpg
# Loaded data from MP_Data3\this\36.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\37.jpg
# Loaded data from MP_Data3\this\37.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\38.jpg
# Loaded data from MP_Data3\this\38.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\39.jpg
# Loaded data from MP_Data3\this\39.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\4.jpg
# Loaded data from MP_Data3\this\4.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\40.jpg
# Loaded data from MP_Data3\this\40.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\41.jpg
# Loaded data from MP_Data3\this\41.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\42.jpg
# Loaded data from MP_Data3\this\42.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\43.jpg
# Loaded data from MP_Data3\this\43.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\44.jpg
# Loaded data from MP_Data3\this\44.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\45.jpg
# Loaded data from MP_Data3\this\45.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\46.jpg
# Loaded data from MP_Data3\this\46.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\47.jpg
# Loaded data from MP_Data3\this\47.npy, shape: (126,)
# Skipping non-npy file: MP_Data3\this\48.jpg
# Loaded data from MP_Data3\this\48.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\49.jpg
# Loaded data from MP_Data3\this\49.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\5.jpg
# Loaded data from MP_Data3\this\5.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\6.jpg
# Loaded data from MP_Data3\this\6.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\7.jpg
# Loaded data from MP_Data3\this\7.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\8.jpg
# Loaded data from MP_Data3\this\8.npy, shape: (63,)
# Skipping non-npy file: MP_Data3\this\9.jpg
# Loaded data from MP_Data3\this\9.npy, shape: (63,)
# Maximum sequence length found: 126
# Loaded 200 samples and 200 labels.
# Sample X shape: (200, 126)
# Sample y shape: (200,)
# Actions: ['hello' 'prototype' 'seeyoulater' 'this']
# y_encoded shape: (200, 4)
# Training samples: 160, Test samples: 40

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

# Define a simple feedforward neural network
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=15, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Save the model
model.save('action_recognition_model.h5')
# Out:
# C:\Users\Acer\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.2667 - loss: 1.4133 - val_accuracy: 0.3750 - val_loss: 1.3059
# Epoch 2/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3375 - loss: 1.2927 - val_accuracy: 0.3438 - val_loss: 1.2477
# Epoch 3/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6021 - loss: 1.2373 - val_accuracy: 0.7812 - val_loss: 1.1842
# Epoch 4/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8542 - loss: 1.1659 - val_accuracy: 1.0000 - val_loss: 1.1165
# Epoch 5/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9563 - loss: 1.1023 - val_accuracy: 1.0000 - val_loss: 1.0437
# Epoch 6/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 1.0506 - val_accuracy: 1.0000 - val_loss: 0.9767
# Epoch 7/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.9552 - val_accuracy: 1.0000 - val_loss: 0.9076
# Epoch 8/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.8565 - val_accuracy: 1.0000 - val_loss: 0.8309
# Epoch 9/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.8257 - val_accuracy: 1.0000 - val_loss: 0.7606
# Epoch 10/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.7564 - val_accuracy: 1.0000 - val_loss: 0.6999
# Epoch 11/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.6545 - val_accuracy: 1.0000 - val_loss: 0.6431
# Epoch 12/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.6522 - val_accuracy: 1.0000 - val_loss: 0.5973
# Epoch 13/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.5699 - val_accuracy: 1.0000 - val_loss: 0.5542
# Epoch 14/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.5120 - val_accuracy: 1.0000 - val_loss: 0.5077
# Epoch 15/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.4662 - val_accuracy: 1.0000 - val_loss: 0.4743
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.4807
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 100.00%

# %%
import cv2
import os
import numpy as np

def load_data(data_dir):
    images = []
    labels = []
    class_names = []
    
    class_to_index = {}
    index = 0
    
    # Define acceptable image extensions
    valid_extensions = ['.jpg', '.jpeg', '.png']
    
    # Iterate through directories and load images
    for class_name in os.listdir(data_dir):
        class_dir = os.path.join(data_dir, class_name)
        if os.path.isdir(class_dir):
            class_names.append(class_name)
            class_to_index[class_name] = index
            index += 1
            
            for filename in os.listdir(class_dir):
                file_path = os.path.join(class_dir, filename)
                ext = os.path.splitext(filename)[1].lower()
                
                if ext not in valid_extensions:
                    print(f"Skipping unsupported file {file_path}")
                    continue
                
                # Load and preprocess image
                img = cv2.imread(file_path)
                
                if img is None:
                    print(f"Warning: Unable to load image {file_path}")
                    continue
                
                # Ensure the image is resized properly
                try:
                    img = cv2.resize(img, (50, 50))  # Use the same image_size as defined
                except cv2.error as e:
                    print(f"Error resizing image {file_path}: {e}")
                    continue
                
                images.append(img)
                labels.append(class_to_index[class_name])  # Convert label to integer
    
    images = np.array(images)
    labels = np.array(labels)
    return images, labels, class_names

# %%
# Assuming the directory structure is as follows:
# MP_Data/
# ├── hello/
# │   ├── 0.jpg
# │   ├── 1.jpg
# │   └── 2.jpg
# ├── thanks/
# │   ├── 0.jpg
# │   ├── 1.jpg
# │   └── 2.jpg
# └── iloveyou/
#     ├── 0.jpg
#     ├── 1.jpg
#     └── 2.jpg

import os
import cv2
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Directory containing action folders
data_dir = 'MP_Data3'

# Initialize variables to store images and labels
images = []
labels = []
class_names = []

# Dictionary to map class names to indices
class_to_index = {}
index = 0

# Define the target image size
image_size = (50, 50)  # Update as needed

# Iterate through each action folder
for class_name in os.listdir(data_dir):
    class_dir = os.path.join(data_dir, class_name)
    if os.path.isdir(class_dir):
        class_names.append(class_name)
        class_to_index[class_name] = index
        index += 1
        
        for filename in os.listdir(class_dir):
            file_path = os.path.join(class_dir, filename)
            ext = os.path.splitext(filename)[1].lower()
            
            if ext in ['.jpg', '.jpeg', '.png']:
                # Load and resize image
                img = cv2.imread(file_path)
                if img is not None:
                    img = cv2.resize(img, image_size)
                    images.append(img)
                    labels.append(class_to_index[class_name])

# Convert lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# Normalize images to the range [0, 1]
images = images.astype('float32') / 255.0

# One-hot encode labels
labels = to_categorical(labels, num_classes=len(class_names))

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Build a simple CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(50, 50, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(class_names), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

# Save the trained model
model.save('action_recognition_model.h5')
# Out:
# Epoch 1/10
# C:\Users\Acer\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.3537 - loss: 1.5643 - val_accuracy: 0.6750 - val_loss: 1.1032
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7219 - loss: 1.0180 - val_accuracy: 0.6250 - val_loss: 0.8785
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8265 - loss: 0.6145 - val_accuracy: 1.0000 - val_loss: 0.4429
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9668 - loss: 0.3403 - val_accuracy: 1.0000 - val_loss: 0.1948
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9979 - loss: 0.1583 - val_accuracy: 1.0000 - val_loss: 0.1429
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9923 - loss: 0.0748 - val_accuracy: 1.0000 - val_loss: 0.0403
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9915 - loss: 0.0323 - val_accuracy: 1.0000 - val_loss: 0.0188
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9923 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 0.0345
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9923 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0047
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
model.save('action_recognition_model.h5')


print(model.input_shape)
def preprocess_image(image):
    image = cv2.resize(image, (50, 50))  # Resize to match model input size
    image = image.astype('float32') / 255.0  # Normalize
    image = image.flatten()  # Flatten the image to a 1D array
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0043
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 100.00%
# (None, 50, 50, 3)

# %%
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Predicted class: prototype

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 48, 48, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 22, 22, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 7744)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │         991,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,036,128 (11.58 MB)
#  Trainable params: 1,012,042 (3.86 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,024,086 (7.72 MB)

# %%
# !pip install pyttsx3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyttsx3
#   Obtaining dependency information for pyttsx3 from https://files.pythonhosted.org/packages/1c/05/e203982f967cbf4959b383a237142b8df1c2cbc6e0174637cd3f5ce3730c/pyttsx3-2.97-py3-none-any.whl.metadata
#   Downloading pyttsx3-2.97-py3-none-any.whl.metadata (3.8 kB)
# Collecting comtypes (from pyttsx3)
#   Obtaining dependency information for comtypes from https://files.pythonhosted.org/packages/b7/be/f329ad3247f323f350395ad02f33937c9f189b0f8862e9319dd90ab0b867/comtypes-1.4.7-py3-none-any.whl.metadata
#   Downloading comtypes-1.4.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Obtaining dependency information for pypiwin32 from https://files.pythonhosted.org/packages/d0/1b/2f292bbd742e369a100c91faa0483172cd91a1a422a6692055ac920946c5/pypiwin32-223-py3-none-any.whl.metadata
#   Downloading pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\programdata\anaconda3\lib\site-packages (from pyttsx3) (305.1)
# Downloading pyttsx3-2.97-py3-none-any.whl (34 kB)
# Downloading comtypes-1.4.7-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.8 kB ? eta -:--:--
#    ---------- ----------------------------- 61.4/226.8 kB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 143.4/226.8 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 226.8/226.8 kB 2.0 MB/s eta 0:00:00
# Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: pypiwin32, comtypes, pyttsx3
# Successfully installed comtypes-1.4.7 pypiwin32-223 pyttsx3-2.97
#   WARNING: The script clear_comtypes_cache.exe is installed in 'C:\Users\Acer\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Acer\AppData\Roaming\Python\Python311\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Quitting...
